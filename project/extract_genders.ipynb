# %%
import requests
from bs4 import BeautifulSoup
import time
import re
import pandas as pd

# %%
def extract_character_names_from_page(soup):
    """
    Extract character names from a single page.
    
    Args:
        soup: BeautifulSoup object of the page
        
    Returns:
        A list of character names from this page
    """
    character_names = []
    
    # Find category content
    category_divs = soup.find_all('div', class_='category-page__member-left')
    
    for div in category_divs:
        # Find all characters within each category group
        characters = div.find_all('a')
        for character in characters:
            # Get the title (character name)
            name = character.get("title")
            if name:
                character_names.append(name)
    
    return character_names

def find_next_page_link(soup, base_url, previous_url):
    """
    Find the 'next page' link if it exists.
    
    Args:
        soup: BeautifulSoup object of the page
        
    Returns:
        URL of the next page or None if no next page exists
    """
    # Find category content
    category_divs = soup.find_all('div', class_='category-page__pagination')
    
    for div in category_divs:
        # Find next page div
        next_page = div.find_all('a')
        for page in next_page:
            # Get the title (character name)
            href = page.get("href")
            # Avoid going back to the first page or going back to the previous page 
            if href != base_url and href != previous_url:
                return href
    
    return None

def extract_all_character_names(base_url, limit):
    """
    Extract all character names from Disney Wiki category page,
    following pagination to get all pages.
    
    Args:
        base_url: The URL of the Disney Wiki category page
        
    Returns:
        A list of all character names across all pages
    """
    all_names = []
    previous_url = None
    current_url = base_url
    page_count = 0
    
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
    }
    
    while current_url:
        page_count += 1
        print(f"Scraping page {page_count}...")
        print(f"URL: {current_url}")
        
        try:
            # Send GET request
            response = requests.get(current_url, headers=headers)
            response.raise_for_status()
            
            # Parse HTML
            soup = BeautifulSoup(response.content, 'html.parser')
            
            # Extract names from this page
            names = extract_character_names_from_page(soup)
            all_names.extend(names)
            print(f"Found {len(names)} characters on this page")
            print(f"Total so far: {len(all_names)}\n")
            
            # There are only limited names in the wesbite; the last page redirects to the first page!
            if len(all_names) <= limit:
                # Find next page
                next_url = find_next_page_link(soup, base_url, previous_url)
                
                if next_url:
                    previous_url = current_url
                    current_url = next_url
                    # Be polite to the server - add a small delay
                    time.sleep(1)
                else:
                    print("No more pages found. Scraping complete!")
                    current_url = None
            else:
                print("Reached the end of unique pages. Scraping complete!")
                current_url = None
                
        except Exception as e:
            print(f"Error on page {page_count}: {e}")
            break
    
    return all_names

def extract_all_gendered_names(url, gender, limit):
    
    print("=" * 60)
    print(f"Disney  {gender} characters scraper")
    print("=" * 60)
    print(f"Starting URL: {url}\n")
    
    try:
        names = extract_all_character_names(url, limit)
        
        print("\n" + "=" * 60)
        print(f"✓ Scraping Complete!")
        print(f"Total {gender} characters found: {len(names)}")
        print("=" * 60 + "\n")
        
        # Save to file
        output_file = f'disney_{gender}_characters.txt'
        with open(output_file, 'w', encoding='utf-8') as f:
            for name in names:
                f.write(f"{name}\n")
        
        print(f"\n✓ All {len(names)} character names saved to '{output_file}'")
        
        return names
        
    except Exception as e:
        print(f"Error: {e}")
        return []

def main():

    extract_all_gendered_names("https://disney.fandom.com/wiki/Category:Females", "female", 6020)
    extract_all_gendered_names("https://disney.fandom.com/wiki/Category:Males", "male", 10802)


if __name__ == "__main__":
    character_list = main()
# Out:
# ============================================================
# Disney  female characters scraper
# ============================================================
# Starting URL: https://disney.fandom.com/wiki/Category:Females
#
# Scraping page 1...
# URL: https://disney.fandom.com/wiki/Category:Females
# Found 199 characters on this page
# Total so far: 199
#
# Scraping page 2...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Antonia+Bello
# Found 197 characters on this page
# Total so far: 396
#
# Scraping page 3...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Beagle%2C+Boom-Boom%0ABoom-Boom+Beagle
# Found 198 characters on this page
# Total so far: 594
#
# Scraping page 4...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Booby%2C+Mrs.%0AMrs.+Booby
# Found 199 characters on this page
# Total so far: 793
#
# Scraping page 5...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Carlotta
# Found 200 characters on this page
# Total so far: 993
#
# Scraping page 6...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Cinderella+%28Into+the+Woods%29
# Found 197 characters on this page
# Total so far: 1190
#
# Scraping page 7...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Cunningham%2C+Rebecca%0ARebecca+Cunningham
# Found 197 characters on this page
# Total so far: 1387
#
# Scraping page 8...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Discarded+Fun+Meal+Toys
# Found 197 characters on this page
# Total so far: 1584
#
# Scraping page 9...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Ellie+O%27Brien
# Found 200 characters on this page
# Total so far: 1784
#
# Scraping page 10...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Flaversham%2C+Olivia%0AOlivia+Flaversham
# Found 199 characters on this page
# Total so far: 1983
#
# Scraping page 11...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Gish%2C+Annabeth%0AAnnabeth+Gish
# Found 198 characters on this page
# Total so far: 2181
#
# Scraping page 12...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Hall%2C+Rebecca%0ARebecca+Hall
# Found 199 characters on this page
# Total so far: 2380
#
# Scraping page 13...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Hotshot+and+Flygirl
# Found 200 characters on this page
# Total so far: 2580
#
# Scraping page 14...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Jessica+%28Stitch%21%29
# Found 199 characters on this page
# Total so far: 2779
#
# Scraping page 15...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Kiki+%28T.O.T.S.%29
# Found 197 characters on this page
# Total so far: 2976
#
# Scraping page 16...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Leighton%2C+Amanda%0AAmanda+Leighton
# Found 198 characters on this page
# Total so far: 3174
#
# Scraping page 17...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Ma+Pines
# Found 200 characters on this page
# Total so far: 3374
#
# Scraping page 18...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Mary+%28Dog+with+a+Blog%29
# Found 196 characters on this page
# Total so far: 3570
#
# Scraping page 19...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Milady+de+Winter
# Found 200 characters on this page
# Total so far: 3770
#
# Scraping page 20...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Mr.+and+Mrs.+Sato
# Found 198 characters on this page
# Total so far: 3968
#
# Scraping page 21...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Nova+Bright
# Found 199 characters on this page
# Total so far: 4167
#
# Scraping page 22...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Paxton%2C+Sara%0ASara+Paxton
# Found 199 characters on this page
# Total so far: 4366
#
# Scraping page 23...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Precious
# Found 196 characters on this page
# Total so far: 4562
#
# Scraping page 24...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Rhodes%2C+Kim%0AKim+Rhodes
# Found 200 characters on this page
# Total so far: 4762
#
# Scraping page 25...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Sally+Jackson
# Found 199 characters on this page
# Total so far: 4961
#
# Scraping page 26...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Silver+Queen
# Found 198 characters on this page
# Total so far: 5159
#
# Scraping page 27...
# URL: https://disney.fandom.com/wiki/Category:Females?from=StellaLou
# Found 200 characters on this page
# Total so far: 5359
#
# Scraping page 28...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Terry
# Found 199 characters on this page
# Total so far: 5558
#
# Scraping page 29...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Tyrannosaurus+Rex
# Found 198 characters on this page
# Total so far: 5756
#
# Scraping page 30...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Wenches
# Found 198 characters on this page
# Total so far: 5954
#
# Scraping page 31...
# URL: https://disney.fandom.com/wiki/Category:Females?from=Zielinski%2C+Kathy%0AKathy+Zielinski
# Found 20 characters on this page
# Total so far: 5974
#
# No more pages found. Scraping complete!
#
# ============================================================
# ✓ Scraping Complete!
# Total female characters found: 5974
# ============================================================
#
#
# ✓ All 5974 character names saved to 'disney_female_characters.txt'
# ============================================================
# Disney  males characters scraper
# ============================================================
# Starting URL: https://disney.fandom.com/wiki/Category:Males
#
# Scraping page 1...
# URL: https://disney.fandom.com/wiki/Category:Males
# Found 199 characters on this page
# Total so far: 199
#
# Scraping page 2...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Andy+Ape
# Found 200 characters on this page
# Total so far: 399
#
# Scraping page 3...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Baby+Shelby
# Found 200 characters on this page
# Total so far: 599
#
# Scraping page 4...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Beast
# Found 199 characters on this page
# Total so far: 798
#
# Scraping page 5...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Black+Bolt
# Found 200 characters on this page
# Total so far: 998
#
# Scraping page 6...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Boy+Beaver
# Found 199 characters on this page
# Total so far: 1197
#
# Scraping page 7...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Bud+and+Sylvia+Newman
# Found 200 characters on this page
# Total so far: 1397
#
# Scraping page 8...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Captain+America+%28The+Avengers%3A+Earth%27s+Mightiest+Heroes%29
# Found 200 characters on this page
# Total so far: 1597
#
# Scraping page 9...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Charon
# Found 199 characters on this page
# Total so far: 1796
#
# Scraping page 10...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Clifford
# Found 200 characters on this page
# Total so far: 1996
#
# Scraping page 11...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Cooper%2C+Ernie%0AErnie+Cooper
# Found 198 characters on this page
# Total so far: 2194
#
# Scraping page 12...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Da+Vinci%2C+Leonardo%0ALeonardo+da+Vinci
# Found 200 characters on this page
# Total so far: 2394
#
# Scraping page 13...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Dennis%0ADennis+%28Stanley%29
# Found 200 characters on this page
# Total so far: 2594
#
# Scraping page 14...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Domino
# Found 198 characters on this page
# Total so far: 2792
#
# Scraping page 15...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Earl+%28The+Good+Dinosaur%29
# Found 199 characters on this page
# Total so far: 2991
#
# Scraping page 16...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Ewan
# Found 198 characters on this page
# Total so far: 3189
#
# Scraping page 17...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Firebird%0AThe+Firebird
# Found 199 characters on this page
# Total so far: 3388
#
# Scraping page 18...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Freberg%2C+Stan%0AStan+Freberg
# Found 199 characters on this page
# Total so far: 3587
#
# Scraping page 19...
# URL: https://disney.fandom.com/wiki/Category:Males?from=General+Are
# Found 197 characters on this page
# Total so far: 3784
#
# Scraping page 20...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Good+King
# Found 197 characters on this page
# Total so far: 3981
#
# Scraping page 21...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Grover+Brady
# Found 199 characters on this page
# Total so far: 4180
#
# Scraping page 22...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Hartman%2C+Butch%0AButch+Hartman
# Found 199 characters on this page
# Total so far: 4379
#
# Scraping page 23...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Hodges%2C+Eric+%22Ty%22%0ATy+Hodges
# Found 198 characters on this page
# Total so far: 4577
#
# Scraping page 24...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Icarus
# Found 200 characters on this page
# Total so far: 4777
#
# Scraping page 25...
# URL: https://disney.fandom.com/wiki/Category:Males?from=James%2C+Brian+d%27Arcy%0ABrian+d%27Arcy+James
# Found 199 characters on this page
# Total so far: 4976
#
# Scraping page 26...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Jones%2C+Alex+Christian%0AAlex+Christian+Jones
# Found 200 characters on this page
# Total so far: 5176
#
# Scraping page 27...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Keno+Kentrix
# Found 196 characters on this page
# Total so far: 5372
#
# Scraping page 28...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Kozak%0ADr.+Kozak
# Found 200 characters on this page
# Total so far: 5572
#
# Scraping page 29...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Lendrum%0ALibrarian+Lendrum
# Found 198 characters on this page
# Total so far: 5770
#
# Scraping page 30...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Louie+%28TaleSpin%29
# Found 200 characters on this page
# Total so far: 5970
#
# Scraping page 31...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Malick%2C+Nathaniel%0ANathaniel+Malick
# Found 198 characters on this page
# Total so far: 6168
#
# Scraping page 32...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Mayan+Clan
# Found 198 characters on this page
# Total so far: 6366
#
# Scraping page 33...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Meyer%2C+Peyton%0APeyton+Meyer
# Found 198 characters on this page
# Total so far: 6564
#
# Scraping page 34...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Morita%2C+Pat%0APat+Morita
# Found 199 characters on this page
# Total so far: 6763
#
# Scraping page 35...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Narrator+%28The+Twilight+Zone%29
# Found 198 characters on this page
# Total so far: 6961
#
# Scraping page 36...
# URL: https://disney.fandom.com/wiki/Category:Males?from=NRR+95%2FSandboxes%2FLeland+Turbo
# Found 196 characters on this page
# Total so far: 7157
#
# Scraping page 37...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Oso
# Found 197 characters on this page
# Total so far: 7354
#
# Scraping page 38...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Peevy
# Found 200 characters on this page
# Total so far: 7554
#
# Scraping page 39...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Piven%2C+Jeremy%0AJeremy+Piven
# Found 197 characters on this page
# Total so far: 7751
#
# Scraping page 40...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Proud%2C+BeBe+%26+CeCe%0ABeBe+%26+CeCe+Proud
# Found 200 characters on this page
# Total so far: 7951
#
# Scraping page 41...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Razorbacks
# Found 199 characters on this page
# Total so far: 8150
#
# Scraping page 42...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Robbins%2C+Tom+Alan%0ATom+Alan+Robbins
# Found 197 characters on this page
# Total so far: 8347
#
# Scraping page 43...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Rumplestiltskin
# Found 199 characters on this page
# Total so far: 8546
#
# Scraping page 44...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Schweiger%2C+Til%0ATil+Schweiger
# Found 197 characters on this page
# Total so far: 8743
#
# Scraping page 45...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Sheriff+Gomer+Cleghorn+and+Deputy+Wendell
# Found 199 characters on this page
# Total so far: 8942
#
# Scraping page 46...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Smee%0AMr.+Smee
# Found 199 characters on this page
# Total so far: 9141
#
# Scraping page 47...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Squirt+%28Finding+Nemo%29
# Found 200 characters on this page
# Total so far: 9341
#
# Scraping page 48...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Super+Beagle+Boy
# Found 199 characters on this page
# Total so far: 9540
#
# Scraping page 49...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Thatcher%2C+Kirk%0AKirk+Thatcher
# Found 199 characters on this page
# Total so far: 9739
#
# Scraping page 50...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Toons
# Found 199 characters on this page
# Total so far: 9938
#
# Scraping page 51...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Ty+Blue
# Found 197 characters on this page
# Total so far: 10135
#
# Scraping page 52...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Vogel%2C+Preston%0APreston+Vogel
# Found 197 characters on this page
# Total so far: 10332
#
# Scraping page 53...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Whitman%2C+Finn%0AFinn+Whitman
# Found 200 characters on this page
# Total so far: 10532
#
# Scraping page 54...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Wrapper%2C+Fud%0AF%C5%ABd+Wrapper
# Found 199 characters on this page
# Total so far: 10731
#
# Scraping page 55...
# URL: https://disney.fandom.com/wiki/Category:Males?from=Z%C3%A9+Galo
# Found 2 characters on this page
# Total so far: 10733
#
# No more pages found. Scraping complete!
#
# ============================================================
# ✓ Scraping Complete!
# Total males characters found: 10733
# ============================================================
#
#
# ✓ All 10733 character names saved to 'disney_males_characters.txt'

# %%
with open(r"disney_female_characters.txt", "r", encoding="utf-8") as f:
    female_names = f.read().splitlines()

with open(r"disney_male_characters.txt", "r", encoding="utf-8") as f:
    male_names = f.read().splitlines()

# %%
cleaned_female_names_dict = {name.split('(')[0].strip(): 'F' for name in female_names}
cleaned_male_names_dict = {name.split('(')[0].strip(): 'M' for name in male_names}
all_names = cleaned_female_names_dict | cleaned_male_names_dict

# %%
names_df = pd.DataFrame(all_names.items(), columns=['Name', 'Gender'])
names_df.to_csv('disney_names_and_genders.csv')
